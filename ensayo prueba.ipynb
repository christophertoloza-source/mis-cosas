# %%
stock=[12,8,7,4,5]
compras=sum(stock)
for i in stock:
    if i<10:
     print(i,"alerta:hay un producto con bajo stock")
# Out:
# 8 alerta:hay un producto con bajo stock
# 7 alerta:hay un producto con bajo stock
# 4 alerta:hay un producto con bajo stock
# 5 alerta:hay un producto con bajo stock

# %%
encuesta=[[4.4,3.5,7.0],#persona 1
         [5.6,6.9,1.7],#persona 2
         [1.0,2.0,1.5]#persona 3
]
for persona in encuesta: 
    suma = 0
    for nota in persona:
        suma = suma + nota
    promedio = suma / 3
    print("El promedio de la personaes:",promedio)
    if promedio <3:
        print("Alerta: esta persona tiene un promedio menor a 3")
suma_p1=0
suma_p2=0
suma_p3=0
for i in range(3):
    suma_p1 = suma_p1 + encuesta[i][0]
    suma_p2 = suma_p2 + encuesta[i][1]
    suma_p3 = suma_p3 + encuesta[i][2]

promedio_1 = suma_p1 / 3
promedio_p2 = suma_p2 / 3
promedio_p3 = suma_p3 / 3
print(f"El promedio de la pregunta 1 es:{promedio_1}")
print(f"El promedio de la pregunta 2 es:{promedio_p2}")
print(f"El pomedio de la pregunta 3 es: {promedio_p3}")
# Out:
# El promedio de la personaes: 4.966666666666667
# El promedio de la personaes: 4.733333333333333
# El promedio de la personaes: 1.5
# Alerta: esta persona tiene un promedio menor a 3
# El promedio de la pregunta 1 es:3.6666666666666665
# El promedio de la pregunta 2 es:4.133333333333334
# El pomedio de la pregunta 3 es: 3.4

# %%
edad=int(input("ingrese su edad"))
membresia=input("¿tiene membresia activa?(s/n):")
invitado=input("¿tiene código de invitado?(s/n)")

if edad>=18 and(membresia =="s" or invitado=="s"):
    print("Acseso permitido")
else:
    print("aceso denegado")
# Out:
# Acseso permitido
